# %% [markdown]
# # LangGraph Overview and Visualization
#
# This notebook compiles a minimal interviewer graph and visualizes a sample run.

# %%
from ai_interviewer_pm.agents.graph import compile_graph
app = compile_graph()
state = {"question": "Tell me about a time you influenced without authority", "answer": "..."}
# Note: Requires OPENAI_API_KEY configured
for event in app.stream(state, stream_mode="values"):
    display(event)
