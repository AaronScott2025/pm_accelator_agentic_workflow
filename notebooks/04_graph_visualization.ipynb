# %% [markdown]
# # Graph Visualization
#
# Render and inspect the LangGraph DAG.

# %%
from ai_interviewer_pm.agents.graph import build_graph
g = build_graph()
try:
    from langgraph.graph import draw_graph
    svg = draw_graph(g).draw_mermaid_png()
    display(svg)
except Exception as e:
    print('Install graphviz/mermaid support to render:', e)
